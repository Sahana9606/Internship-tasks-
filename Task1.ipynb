# %%
import pandas as pd

df = pd.read_csv("mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customerid              200 non-null    int64
#  1   gender                  200 non-null    object
#  2   age                     200 non-null    datetime64[ns]
#  3   annual_income_(k$)      200 non-null    int64
#  4   spending_score_(1-100)  200 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        customerid                            age  annual_income_(k$)  \
# count  200.000000                            200          200.000000
# mean   100.500000  1970-01-01 00:00:00.000000038           60.560000
# min      1.000000  1970-01-01 00:00:00.000000018           15.000000
# 25%     50.750000  1970-01-01 00:00:00.000000028           41.500000
# 50%    100.500000  1970-01-01 00:00:00.000000036           61.500000
# 75%    150.250000  1970-01-01 00:00:00.000000049           78.000000
# max    200.000000  1970-01-01 00:00:00.000000070          137.000000
# std     57.879185                            NaN           26.264721
#
#        spending_score_(1-100)
# count              200.000000
# mean                50.200000
# min                  1.000000
# 25%                 34.750000
# 50%                 50.000000
# 75%                 73.000000
# max                 99.000000
# std                 25.823522

# %%
import pandas as pd
import os

print("mall_Customers.csv:", os.listdir())

df = pd.read_csv("mall_Customers.csv")
print("Loaded shape:", df.shape)

df.head()
# Out:
# mall_Customers.csv: ['.anaconda', '.arduinoIDE', '.conda', '.condarc', '.continuum', '.eclipse', '.gradle', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.m2', '.matplotlib', '.p2', '.spyder-py3', '.streamlit', '.vscode', 'anaconda3', 'AppData', 'Application Data', 'archive (2).zip', 'archive (3).zip', 'attacks.csv', 'Contacts', 'Cookies', 'cyber.csv.csv', 'cyber.ipynb', 'cyberlogin.csv.xlsx', 'cyber_login.csv.xlsx', 'cyber_threats.csv', 'cyber_threats.csv.xlsx', 'data.csv', 'Documents', 'Downloads', 'eclipse', 'eclipse-workspace', 'Favorites', 'Health-Plus-main', 'Links', 'Local Settings', 'login.csv.xlsx', 'Mall_Customers.csv', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TM.blf', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000002.regtrans-ms',
# ...

# %%
df.isnull().sum()
# Out:
# customerid                0
# gender                    0
# age                       0
# annual_income_(k$)        0
# spending_score_(1-100)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.boxplot(figsize=(7,3))
# Out:
# <Axes: >
